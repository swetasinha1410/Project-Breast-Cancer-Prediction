# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import os
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn import metrics

# %%
df=pd.read_csv('C:\\Users\\swsinha\\Desktop\\cancer\\breast-cancer.csv')
df.columns # will print columns name
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
#view dataset
df.head(2)
# Out:
#        id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0  842302         M        17.99         10.38           122.8     1001.0  \
# 1  842517         M        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst
# 0  ...         25.38          17.33            184.6      2019.0  \
# 1  ...         24.99          23.41            158.8      1956.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave_points_worst
# 0            0.1622             0.6656           0.7119                0.2654  \
# 1            0.1238             0.1866           0.2416                0.1860
#
#    symmetry_worst  fractal_dimension_worst
# ...

# %%
#finding any null value
df.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave_points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave_points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave_points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave_points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# return the size of dataset
df.shape
# Out:
# (569, 32)

# %%
# describe the dataset
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000  \
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave_points_mean
# count       569.000000        569.000000      569.000000           569.000000  \
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Get the count of malignant<M> and Benign<B> cells
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
plt.figure(figsize=(4,2))
sns.countplot(x="diagnosis",data=df)
plt.title("cancer prediction")
plt.show()

# %%
#df['diagnosis']=LabelEncoder.fit_transform(df['diagnosis'].values)

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df.diagnosis= le.fit_transform(df.diagnosis.values)

# %%
df.head(2)
# Out:
#        id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0  842302          1        17.99         10.38           122.8     1001.0  \
# 1  842517          1        20.57         17.77           132.9     1326.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst
# 0  ...         25.38          17.33            184.6      2019.0  \
# 1  ...         24.99          23.41            158.8      1956.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave_points_worst
# 0            0.1622             0.6656           0.7119                0.2654  \
# 1            0.1238             0.1866           0.2416                0.1860
#
#    symmetry_worst  fractal_dimension_worst
# ...

# %%
list(le.inverse_transform([0,1]))
# Out:
# ['B', 'M']

# %%
df.shape
# Out:
# (569, 32)

# %%
plt.figure(figsize=(4,2))
sns.pairplot(df.iloc[:,1:6],hue="diagnosis")

# %% [markdown]
# This plot will gives idea about the parmeter w.r.to diagnosis.

# %%
# get the correlation
df.iloc[:,1:32].corr()
# Out:
#                          diagnosis  radius_mean  texture_mean  perimeter_mean
# diagnosis                 1.000000     0.730029      0.415185        0.742636  \
# radius_mean               0.730029     1.000000      0.323782        0.997855
# texture_mean              0.415185     0.323782      1.000000        0.329533
# perimeter_mean            0.742636     0.997855      0.329533        1.000000
# area_mean                 0.708984     0.987357      0.321086        0.986507
# smoothness_mean           0.358560     0.170581     -0.023389        0.207278
# compactness_mean          0.596534     0.506124      0.236702        0.556936
# concavity_mean            0.696360     0.676764      0.302418        0.716136
# concave_points_mean       0.776614     0.822529      0.293464        0.850977
# symmetry_mean             0.330499     0.147741      0.071401        0.183027
# fractal_dimension_mean   -0.012838    -0.311631     -0.076437       -0.261477
# ...

# %%
# visualize the correlation
plt.figure(figsize=(10,10))
sns.heatmap(df.iloc[:,1:10].corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Build Model

# %%
# split the dataset into dependent(X) and Independent(Y) datasets
x=df.iloc[:,2:32]
y=df['diagnosis']

# %%
# spliting the data into trainning and test dateset
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.20,
                                                    random_state=42)

print('Shape of Training Xs:{}'.format(x_train.shape))
print('Shape of Test Xs:{}'.format(x_test.shape))
print('Shape of Training y:{}'.format(y_train.shape))
print('Shape of Test y:{}'.format(y_test.shape))
# Out:
# Shape of Training Xs:(455, 30)
# Shape of Test Xs:(114, 30)
# Shape of Training y:(455,)
# Shape of Test y:(114,)

# %%
clf = LogisticRegression()
clf.fit(x_train, y_train)
y_predicted = clf.predict(x_test)
accuracy_score=accuracy_score(y_test,y_predicted);#testing the linear regression model accuracy score
accuracy_score
# Out:
# 0.9649122807017544

# %%
print("Logistic Regression model accuracy(in %):", 
metrics.accuracy_score(y_test, y_predicted)*100)
# Out:
# Logistic Regression model accuracy(in %): 96.49122807017544

# %%
confusion_matrix=confusion_matrix(y_test,y_predicted)
confusion_matrix
# Out:
# array([[70,  1],
#        [ 3, 40]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        71
#            1       0.98      0.93      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %%
# Prediction on Test Data
y_predicted_labels = le.inverse_transform(y_predicted)
y_predicted_labels[0:20]
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B', 'B', 'M', 'B',
#        'M', 'B', 'M', 'B', 'B', 'B', 'M'], dtype=object)

# %%
true_labels = le.inverse_transform(y_test)
true_labels[0:10]
# Out:
# array(['B', 'M', 'M', 'B', 'B', 'M', 'M', 'M', 'B', 'B'], dtype=object)

# %%
import joblib

joblib.dump(clf,open("Breast_cancer_v1.0.model","wb"))
joblib.dump(le,open("breast_cancer_v1.0.encoder","wb"))

# %%
model1= joblib.load(open("Breast_cancer_v1.0.model","rb"))
encoder=joblib.load(open("breast_cancer_v1.0.encoder","rb"))

# %%
df.iloc[5:6]
# Out:
#        id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 5  843786          1        12.45          15.7           82.57      477.1  \
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean
# 5           0.1278              0.17          0.1578              0.08089  \
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst
# 5  ...         15.47          23.75            103.4       741.6  \
#
#    smoothness_worst  compactness_worst  concavity_worst  concave_points_worst
# 5            0.1791             0.5249           0.5355                0.1741  \
#
#    symmetry_worst  fractal_dimension_worst
# 5          0.3985                   0.1244
#
# [1 rows x 32 columns]

# %%
my_data=df.iloc[9:10]
my_data
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 9  84501001          1        12.46         24.04           83.97      475.9  \
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean
# 9           0.1186            0.2396          0.2273              0.08543  \
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst
# 9  ...         15.09          40.68            97.65       711.4  \
#
#    smoothness_worst  compactness_worst  concavity_worst  concave_points_worst
# 9            0.1853              1.058            1.105                 0.221  \
#
#    symmetry_worst  fractal_dimension_worst
# 9          0.4366                   0.2075
#
# [1 rows x 32 columns]

# %%
my_data_mew=my_data.drop(['id','diagnosis'],axis=1)
my_data_mew
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean
# 9        12.46         24.04           83.97      475.9           0.1186  \
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean
# 9            0.2396          0.2273              0.08543          0.203  \
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst
# 9                 0.08243  ...         15.09          40.68            97.65  \
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst
# 9       711.4            0.1853              1.058            1.105  \
#
#    concave_points_worst  symmetry_worst  fractal_dimension_worst
# 9                 0.221          0.4366                   0.2075
#
# [1 rows x 30 columns]

# %%
model1.predict(my_data_mew)
# Out:
# array([1])
